# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0   0.0
#
#    season     team
# ...

# %%
matches.shape
# Out:
# (1852, 27)

# %%
matches["team"].value_counts()
# Out:
# Leicester City              93
# Aston Villa                 93
# Newcastle United            93
# Southampton                 93
# Tottenham Hotspur           93
# Wolverhampton Wanderers     93
# West Ham United             93
# Everton                     93
# Leeds United                92
# Manchester City             92
# Arsenal                     92
# Crystal Palace              92
# Brighton and Hove Albion    92
# Chelsea                     92
# Liverpool                   92
# Manchester United           92
# Burnley                     76
# Brentford                   55
# Fulham                      55
# Watford                     38
# Norwich City                38
# West Bromwich Albion        38
# Sheffield United            38
# Bournemouth                 17
# Nottingham Forest           17
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 11    60
# Matchweek 2     60
# Matchweek 18    60
# Matchweek 17    60
# Matchweek 15    60
# Matchweek 14    60
# Matchweek 13    60
# Matchweek 16    60
# Matchweek 10    60
# Matchweek 6     60
# Matchweek 5     60
# Matchweek 4     60
# Matchweek 9     60
# Matchweek 3     60
# Matchweek 12    58
# Matchweek 8     54
# Matchweek 34    40
# Matchweek 31    40
# Matchweek 32    40
# Matchweek 30    40
# Matchweek 33    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 28    40
# Matchweek 29    40
# Matchweek 20    40
# Matchweek 27    40
# Matchweek 26    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 19    40
# Matchweek 7     40
# Matchweek 38    40
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2022-08-05  20:00   Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30   Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30   Matchweek 5  Wed  Home      W  2.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...  match report    sh  sot  dist   fk   pk pkatt  \
# 0   Crystal Palace  1.0  ...  Match Report  10.0  2.0  14.6  1.0  0.0   0.0
# ...

# %%
del matches["match report"]

# %%
matches.dtypes
# Out:
# date          datetime64[ns]
# time                  object
# round                 object
# day                   object
# venue                 object
# result                object
# gf                   float64
# ga                   float64
# opponent              object
# xg                   float64
# xga                  float64
# poss                 float64
# attendance           float64
# captain               object
# formation             object
# referee               object
# sh                   float64
# sot                  float64
# dist                 float64
# fk                   float64
# pk                   float64
# pkatt                float64
# season                 int64
# team                  object
# target                 int64
# dtype: object

# %%
matches["attendance"].fillna(0, inplace=True)

# %%
matches["dist"].fillna(0, inplace=True)

# %%
matches.isnull().sum()
# Out:
# date          0
# time          0
# round         0
# day           0
# venue         0
# result        0
# gf            0
# ga            0
# opponent      0
# xg            0
# xga           0
# poss          0
# attendance    0
# captain       0
# formation     0
# referee       0
# sh            0
# sot           0
# dist          0
# fk            0
# pk            0
# pkatt         0
# season        0
# team          0
# target        0
# dtype: int64

# %%
mat = matches.copy()
matk = matches.copy()

# %%
del matk["result"]

# %%
del matk["time"]

# %%
del matk["day"]

# %%
del matk["captain"]

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()

for i in ['round','venue','formation','referee','opponent','team']:
    matk[i] = label.fit_transform(matk[i])

matk.head()
# Out:
#         date  round  venue   gf   ga  opponent   xg  xga  poss  attendance  \
# 0 2022-08-05      0      0  2.0  0.0         7  1.0  1.2  44.0     25286.0
# 1 2022-08-13     11      1  4.0  2.0        11  2.7  0.5  50.0     60033.0
# 2 2022-08-20     22      0  3.0  0.0         2  1.3  0.3  57.0     10423.0
# 3 2022-08-27     32      1  2.0  1.0         9  2.6  0.8  71.0     60164.0
# 4 2022-08-31     33      1  2.0  1.0         1  2.4  0.4  59.0     60012.0
#
#    ...  referee    sh  sot  dist   fk   pk  pkatt  season  team  target
# 0  ...        2  10.0  2.0  14.6  1.0  0.0    0.0    2023     0       1
# 1  ...        5  19.0  7.0  13.0  0.0  0.0    0.0    2023     0       1
# 2  ...        4  14.0  6.0  14.8  0.0  0.0    0.0    2023     0       1
# 3  ...        8  22.0  8.0  15.5  1.0  0.0    0.0    2023     0       1
# 4  ...       19  22.0  8.0  16.3  1.0  0.0    0.0    2023     0       1
#
# [5 rows x 21 columns]

# %%
matk.dtypes
# Out:
# date          datetime64[ns]
# round                  int64
# venue                  int64
# gf                   float64
# ga                   float64
# opponent               int64
# xg                   float64
# xga                  float64
# poss                 float64
# attendance           float64
# formation              int64
# referee                int64
# sh                   float64
# sot                  float64
# dist                 float64
# fk                   float64
# pk                   float64
# pkatt                float64
# season                 int64
# team                   int64
# target                 int64
# dtype: object

# %%
matk.isnull().sum()
# Out:
# date          0
# round         0
# venue         0
# gf            0
# ga            0
# opponent      0
# xg            0
# xga           0
# poss          0
# attendance    0
# formation     0
# referee       0
# sh            0
# sot           0
# dist          0
# fk            0
# pk            0
# pkatt         0
# season        0
# team          0
# target        0
# dtype: int64

# %%
train = matk[matk["date"] < '2022-01-01']

test = matk[matk["date"] > '2022-01-01']

# %%
train.head()
# Out:
#         date  round  venue   gf   ga  opponent   xg  xga  poss  attendance  \
# 1 2021-08-15      0      0  0.0  1.0        20  2.0  1.0  65.0     58262.0
# 2 2021-08-21     11      1  5.0  0.0        16  2.7  0.1  67.0     51437.0
# 3 2021-08-28     22      1  5.0  0.0         0  4.0  0.2  80.0     52276.0
# 4 2021-09-11     32      0  1.0  0.0        11  3.3  0.6  61.0     32087.0
# 6 2021-09-18     33      1  0.0  0.0        19  1.2  0.5  64.0     52698.0
#
#    ...  referee    sh   sot  dist   fk   pk  pkatt  season  team  target
# 1  ...        2  18.0   4.0  17.3  1.0  0.0    0.0    2022    13       0
# 2  ...        7  16.0   4.0  18.5  1.0  0.0    0.0    2022    13       1
# 3  ...       13  25.0  10.0  14.8  0.0  0.0    0.0    2022    13       1
# 4  ...       17  25.0   8.0  14.3  0.0  0.0    0.0    2022    13       1
# 6  ...       10  16.0   1.0  16.4  1.0  0.0    0.0    2022    13       0
#
# [5 rows x 21 columns]

# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
train.columns
# Out:
# Index(['date', 'round', 'venue', 'gf', 'ga', 'opponent', 'xg', 'xga', 'poss',
#        'attendance', 'formation', 'referee', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'target'],
#       dtype='object')

# %%
predictors = ['round', 'venue', 'gf', 'ga', 'opponent', 'xg', 'xga', 'poss',
       'attendance', 'formation', 'referee', 'sh', 'sot', 'dist', 'fk', 'pk',
       'pkatt', 'season', 'team']

# %%
train[predictors]
# Out:
#     round  venue   gf   ga  opponent   xg  xga  poss  attendance  formation  \
# 1       0      0 0.00 1.00        20 2.00 1.00 65.00    58262.00         14
# 2      11      1 5.00 0.00        16 2.70 0.10 67.00    51437.00         14
# 3      22      1 5.00 0.00         0 4.00 0.20 80.00    52276.00         14
# 4      32      0 1.00 0.00        11 3.30 0.60 61.00    32087.00         14
# 6      33      1 0.00 0.00        19 1.20 0.50 64.00    52698.00         14
# ..    ...    ...  ...  ...       ...  ...  ...   ...         ...        ...
# 38     27      0 0.00 4.00        20 0.50 2.20 34.00        0.00          2
# 39     28      1 0.00 2.00         7 0.70 2.00 50.00        0.00          6
# 40     29      0 1.00 0.00         8 1.20 1.40 38.00        0.00          3
# 41     30      0 0.00 1.00        15 0.90 1.60 49.00    10000.00          3
# 42     31      1 1.00 0.00         5 0.50 1.10 43.00     5000.00          3
#
# ...

# %%
test.head()
# Out:
#         date  round  venue   gf   ga  opponent   xg  xga  poss  attendance  \
# 0 2022-08-05      0      0 2.00 0.00         7 1.00 1.20 44.00    25286.00
# 1 2022-08-13     11      1 4.00 2.00        11 2.70 0.50 50.00    60033.00
# 2 2022-08-20     22      0 3.00 0.00         2 1.30 0.30 57.00    10423.00
# 3 2022-08-27     32      1 2.00 1.00         9 2.60 0.80 71.00    60164.00
# 4 2022-08-31     33      1 2.00 1.00         1 2.40 0.40 59.00    60012.00
#
#    ...  referee    sh  sot  dist   fk   pk  pkatt  season  team  target
# 0  ...        2 10.00 2.00 14.60 1.00 0.00   0.00    2023     0       1
# 1  ...        5 19.00 7.00 13.00 0.00 0.00   0.00    2023     0       1
# 2  ...        4 14.00 6.00 14.80 0.00 0.00   0.00    2023     0       1
# 3  ...        8 22.00 8.00 15.50 1.00 0.00   0.00    2023     0       1
# 4  ...       19 22.00 8.00 16.30 1.00 0.00   0.00    2023     0       1
#
# [5 rows x 21 columns]

# %%
models,predictions = clf.fit(train[predictors],test[predictors], train['target'], test['target'])
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 11.44it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# Perceptron                         1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# RandomForestClassifier             0.99               0.99     0.99      0.99
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(n_estimators=100, random_state=0)
ada.fit(train[predictors],train['target'])
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
preds = ada.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)
error
# Out:
# 1.0
